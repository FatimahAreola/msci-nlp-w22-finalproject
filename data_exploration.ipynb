# %%
import os
import csv
import pandas as pd
import numpy  as np

# %%
# !wget -O Data/train_bodies.csv https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/train_bodies.csv
# !wget -O Data/train_stances.csv https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/train_stances.csv
# Out:
# --2022-04-08 20:11:52--  https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/train_bodies.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3752301 (3.6M) [text/plain]
# Saving to: ‘Data/train_bodies.csv’
#
# Data/train_bodies.c 100%[===================>]   3.58M  --.-KB/s    in 0.05s
#
# 2022-04-08 20:11:53 (71.7 MB/s) - ‘Data/train_bodies.csv’ saved [3752301/3752301]
#
# --2022-04-08 20:11:53--  https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/train_stances.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4255300 (4.1M) [text/plain]
# Saving to: ‘Data/train_stances.csv’
#
# Data/train_stances. 100%[===================>]   4.06M  --.-KB/s    in 0.05s
#
# 2022-04-08 20:11:54 (77.2 MB/s) - ‘Data/train_stances.csv’ saved [4255300/4255300]

# %%
df_train_bodies = pd.read_csv('Data/train_bodies.csv')
df_train = pd.read_csv('Data/train_stances.csv')

# %%
df_train_bodies.head()
# Out:
#    Body ID                                        articleBody
# 0        0  A small meteorite crashed into a wooded area i...
# 1        4  Last week we hinted at what was to come as Ebo...
# 2        5  (NEWSER) – Wonder how long a Quarter Pounder w...
# 3        6  Posting photos of a gun-toting child online, I...
# 4        7  At least 25 suspected Boko Haram insurgents we...

# %%
df_train.head()
# Out:
#                                             Headline  Body ID     Stance
# 0  Police find mass graves with at least '15 bodi...      712  unrelated
# 1  Hundreds of Palestinians flee floods in Gaza a...      158      agree
# 2  Christian Bale passes on role of Steve Jobs, a...      137  unrelated
# 3  HBO and Apple in Talks for $15/Month Apple TV ...     1034  unrelated
# 4  Spider burrowed through tourist's stomach and ...     1923   disagree

# %%
df_train.replace('agree',0,True)
df_train.replace('disagree',1,True)
df_train.replace('discuss',2,True)
df_train.replace('unrelated',3,True)

# %%
combined_df_train = df_train.join(df_train_bodies.set_index('Body ID'), on='Body ID')

# %%
combined_df_train.to_csv('Data/combined_df_train.csv')

# %%
combined_df_train
# Out:
#                                                 Headline  Body ID  Stance  \
# 0      Police find mass graves with at least '15 bodi...      712       3
# 1      Hundreds of Palestinians flee floods in Gaza a...      158       0
# 2      Christian Bale passes on role of Steve Jobs, a...      137       3
# 3      HBO and Apple in Talks for $15/Month Apple TV ...     1034       3
# 4      Spider burrowed through tourist's stomach and ...     1923       1
# ...                                                  ...      ...     ...
# 49967  Urgent: The Leader of ISIL 'Abu Bakr al-Baghda...     1681       3
# 49968  Brian Williams slams social media for speculat...     2419       3
# 49969  Mexico Says Missing Students Not Found In Firs...     1156       0
# 49970  US Lawmaker: Ten ISIS Fighters Have Been Appre...     1012       2
# 49971  Shots Heard In Alleged Brown Shooting Recordin...     2044       3
#
#                                              articleBody
# 0      Danny Boyle is directing the untitled film\n\n...
# 1      Hundreds of Palestinians were evacuated from t...
# 2      30-year-old Moscow resident was hospitalized w...
# 3      (Reuters) - A Canadian soldier was shot at the...
# 4      Fear not arachnophobes, the story of Bunbury's...
# ...                                                  ...
# 49967  (CNN) -- Boko Haram laughed off Nigeria's anno...
# 49968  Along with unveiling the Apple Watch earlier t...
# 49969  The bodies found in a mass grave were confirme...
# 49970  Rep. Duncan Hunter (R-CA) told Greta Van Suste...
# 49971  A married TV actor who met a young woman and k...
#
# [49972 rows x 4 columns]

# %%
combined_df_train['Stance'].value_counts(normalize=True) * 100
# Out:
# 3    73.130953
# 2    17.827984
# 0     7.360122
# 1     1.680941
# Name: Stance, dtype: float64

# %%
# combined_df_train['Stance'].plot(kind="bar")

# %% [markdown]
# # Testing Data

# %%
# !wget -O Data/test_bodies.csv https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/competition_test_bodies.csv
# !wget -O Data/test_stances.csv https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/competition_test_stances.csv
# Out:
# --2022-04-08 20:12:17--  https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/competition_test_bodies.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2045680 (2.0M) [text/plain]
# Saving to: ‘Data/test_bodies.csv’
#
# Data/test_bodies.cs 100%[===================>]   1.95M  --.-KB/s    in 0.04s
#
# 2022-04-08 20:12:18 (47.3 MB/s) - ‘Data/test_bodies.csv’ saved [2045680/2045680]
#
# --2022-04-08 20:12:18--  https://raw.githubusercontent.com/FakeNewsChallenge/fnc-1/29d473af2d15278f0464d5e41e4cbe7eb58231f2/competition_test_stances.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2177588 (2.1M) [text/plain]
# Saving to: ‘Data/test_stances.csv’
#
# Data/test_stances.c 100%[===================>]   2.08M  --.-KB/s    in 0.05s
#
# 2022-04-08 20:12:19 (43.8 MB/s) - ‘Data/test_stances.csv’ saved [2177588/2177588]

# %%
df_test_bodies = pd.read_csv('Data/test_bodies.csv')
df_test = pd.read_csv('Data/test_stances.csv')

# %%
df_test.replace('agree',0,True)
df_test.replace('disagree',1,True)
df_test.replace('discuss',2,True)
df_test.replace('unrelated',3,True)

# %%
combined_df_test = df_test.join(df_test_bodies.set_index('Body ID'), on='Body ID')

# %%
combined_df_test.to_csv('Data/combined_df_test.csv')

# %%
combined_df_test
# Out:
#                                                 Headline  Body ID  Stance  \
# 0      Ferguson riots: Pregnant woman loses eye after...     2008       3
# 1      Crazy Conservatives Are Sure a Gitmo Detainee ...     1550       3
# 2      A Russian Guy Says His Justin Bieber Ringtone ...        2       3
# 3      Zombie Cat: Buried Kitty Believed Dead, Meows ...     1793       3
# 4      Argentina's President Adopts Boy to End Werewo...       37       3
# ...                                                  ...      ...     ...
# 25408  The success of the Affordable Care Act is a hu...     2582       0
# 25409  The success of the Affordable Care Act is a hu...     2583       2
# 25410  The success of the Affordable Care Act is a hu...     2584       1
# 25411  The success of the Affordable Care Act is a hu...     2585       1
# 25412  The success of the Affordable Care Act is a hu...     2586       0
#
#                                              articleBody
# 0      A RESPECTED senior French police officer inves...
# 1      Dave Morin's social networking company Path is...
# 2      A bereaved Afghan mother took revenge on the T...
# 3      Hewlett-Packard is officially splitting in two...
# 4      An airline passenger headed to Dallas was remo...
# ...                                                  ...
# 25408  Congressional Republicans, evidently hoping th...
# 25409  Did Obamacare work?\n\nIt’s worth reflecting u...
# 25410  Millions may lose coverage next year if Congre...
# 25411  Come November, the grim trudge across the incr...
# 25412  Remember how much Republicans wanted to repeal...
#
# [25413 rows x 4 columns]

# %%
combined_df_test['Stance'].value_counts(normalize=True) * 100
# Out:
# 3    72.203203
# 2    17.565813
# 0     7.488293
# 1     2.742691
# Name: Stance, dtype: float64

# %%
# combined_df_test['Stance'].plot(kind="bar")

# %%
to_remove = np.random.choice(combined_df_train[combined_df_train['Stance']==3].index,size=17990,replace=False)

# %%
new_combined_df_train = combined_df_train.drop(to_remove)

# %%
combined_df_train
# Out:
#                                                 Headline  Body ID  Stance  \
# 0      Police find mass graves with at least '15 bodi...      712       3
# 1      Hundreds of Palestinians flee floods in Gaza a...      158       0
# 2      Christian Bale passes on role of Steve Jobs, a...      137       3
# 3      HBO and Apple in Talks for $15/Month Apple TV ...     1034       3
# 4      Spider burrowed through tourist's stomach and ...     1923       1
# ...                                                  ...      ...     ...
# 49967  Urgent: The Leader of ISIL 'Abu Bakr al-Baghda...     1681       3
# 49968  Brian Williams slams social media for speculat...     2419       3
# 49969  Mexico Says Missing Students Not Found In Firs...     1156       0
# 49970  US Lawmaker: Ten ISIS Fighters Have Been Appre...     1012       2
# 49971  Shots Heard In Alleged Brown Shooting Recordin...     2044       3
#
#                                              articleBody
# 0      Danny Boyle is directing the untitled film\n\n...
# 1      Hundreds of Palestinians were evacuated from t...
# 2      30-year-old Moscow resident was hospitalized w...
# 3      (Reuters) - A Canadian soldier was shot at the...
# 4      Fear not arachnophobes, the story of Bunbury's...
# ...                                                  ...
# 49967  (CNN) -- Boko Haram laughed off Nigeria's anno...
# 49968  Along with unveiling the Apple Watch earlier t...
# 49969  The bodies found in a mass grave were confirme...
# 49970  Rep. Duncan Hunter (R-CA) told Greta Van Suste...
# 49971  A married TV actor who met a young woman and k...
#
# [49972 rows x 4 columns]

# %%
new_combined_df_train
# Out:
#                                                 Headline  Body ID  Stance  \
# 0      Police find mass graves with at least '15 bodi...      712       3
# 1      Hundreds of Palestinians flee floods in Gaza a...      158       0
# 4      Spider burrowed through tourist's stomach and ...     1923       1
# 5      'Nasa Confirms Earth Will Experience 6 Days of...      154       0
# 7      Identity of ISIS terrorist known as 'Jihadi Jo...     2033       3
# ...                                                  ...      ...     ...
# 49967  Urgent: The Leader of ISIL 'Abu Bakr al-Baghda...     1681       3
# 49968  Brian Williams slams social media for speculat...     2419       3
# 49969  Mexico Says Missing Students Not Found In Firs...     1156       0
# 49970  US Lawmaker: Ten ISIS Fighters Have Been Appre...     1012       2
# 49971  Shots Heard In Alleged Brown Shooting Recordin...     2044       3
#
#                                              articleBody
# 0      Danny Boyle is directing the untitled film\n\n...
# 1      Hundreds of Palestinians were evacuated from t...
# 4      Fear not arachnophobes, the story of Bunbury's...
# 5      Thousands of people have been duped by a fake ...
# 7      Adding to Apple's iOS 8 launch troubles, a rep...
# ...                                                  ...
# 49967  (CNN) -- Boko Haram laughed off Nigeria's anno...
# 49968  Along with unveiling the Apple Watch earlier t...
# 49969  The bodies found in a mass grave were confirme...
# 49970  Rep. Duncan Hunter (R-CA) told Greta Van Suste...
# 49971  A married TV actor who met a young woman and k...
#
# [31982 rows x 4 columns]

# %%
new_combined_df_train['Stance'].value_counts(normalize=True) * 100
# Out:
# 3    58.017010
# 2    27.856294
# 0    11.500219
# 1     2.626477
# Name: Stance, dtype: float64
